# %%
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]
# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

#Create the plot
plt.plot(x_axis, y_axis)

# %%
#Create the plot with the ax.plt () mehtod
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
#Create the plot with the ax.plt() 
fig = plt.figure()
ax = fig.add_subplot()

# %%
# Creating a graph with the ax.plt() method
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot and add a label for the legend
plt.plot(x_axis, y_axis, marker = "*", color = "blue", linewidth = 2, label = "Boston")

# Create labels for the x and y axis
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Set the y limit between 0 adn 45. 
plt.ylim(0,45)

# Create a title
plt.title("Pyber Fare by Month")

#Add a grid
plt.grid()

#Add the legend
plt.legend()

# %%
plt.plot(x_axis, y_axis, color = "green", marker="d", linewidth = 2, label = "Boston")
plt.xlabel("Date")
plt.ylabel("Fare($)")
plt.grid()
plt.title("Pyber Fare by Month")
plt.legend()
plt.ylim(0,45)
# Out:
# (0.0, 45.0)

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot 
plt.bar(x_axis, y_axis, color = "green", label = "Boston")

# Create lables for y and x axis
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Create a title
plt.title("PyBer Fare by Month")

# Add the legend
plt.legend()

# %%
# Create the hbar plot 
plt.barh(x_axis, y_axis, label = "Boston", color = "green")

plt.xlabel("Date")
plt.ylabel("Fare")
plt.legend()
plt.title("PyBer Fare by Month")

plt.gca().invert_yaxis()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, color = "k", label = "New York")
# Out:
# <BarContainer object of 12 artists>

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]
# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.scatter(y_axis, x_axis, c="red", marker = "x")
plt.legend("Chicago")
plt.title("PyBer Fare by Month")
plt.gca().invert_yaxis()
plt.xlim(0,50)
# Out:
# (0.0, 50.0)

# %%
# Comprehension list to increase size of bubble chart markers 
plt.scatter(y_axis, x_axis, c = "blue", s=[i * 5 for i in y_axis], label = "Boston")
plt.legend("PyBer Fare by Month")
plt.xlabel("Fare $")
plt.ylabel("Date")
# Out:
# Text(0, 0.5, 'Date')

# %%
# Assign 12 colors, one for each month.
plt.subplots(figsize = (8,8))
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, 
        explode=explode_values,
        colors=colors,
        shadow = True,
        startangle=90,
        labels=x_axis,
        counterclock = False,
        autopct='%.1f%%')
plt.show()
